# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Paths to the datasets
base_path = r"D:\Earth Observatiion\Earth Observe"

# %%
# Parameters
img_size = (224, 224)  # Standard input size for MobileNetV2
batch_size = 32

# %%
# Load and split the data into training, validation, and testing sets
files = []
labels = []
for label in os.listdir(base_path):
    class_dir = os.path.join(base_path, label)
    if os.path.isdir(class_dir):
        files.extend([os.path.join(class_dir, f) for f in os.listdir(class_dir)])
        labels.extend([label] * len(os.listdir(class_dir)))

# %%
# Split data into training+validation and testing sets first
train_valid_files, test_files, train_valid_labels, test_labels = train_test_split(
    files, labels, test_size=0.15, random_state=42
)

# Split training+validation into training and validation sets
train_files, valid_files, train_labels, valid_labels = train_test_split(
    train_valid_files, train_valid_labels, test_size=0.1765, random_state=42  # 0.1765 is approximately 15% of 85%
)

# %%
 #ImageDataGenerators for training, validation, and testing
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=40,             # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,         # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,        # randomly shift images vertically (fraction of total height)
    shear_range=0.2,               # apply shearing transformation
    zoom_range=0.2,                # randomly zoom into images
    horizontal_flip=True,          # randomly flip images horizontally
    fill_mode='nearest'            # strategy for filling in newly created pixels, which can appear after a rotation or a width/height shift
).flow_from_dataframe(
    pd.DataFrame({'filepaths': train_files, 'labels': train_labels}),
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
    batch_size=batch_size
)
valid_gen = ImageDataGenerator(preprocessing_function=preprocess_input).flow_from_dataframe(
    pd.DataFrame({'filepaths': valid_files, 'labels': valid_labels}),
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    batch_size=batch_size
)

test_gen = ImageDataGenerator(preprocessing_function=preprocess_input).flow_from_dataframe(
    pd.DataFrame({'filepaths': test_files, 'labels': test_labels}),
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    batch_size=batch_size
)
# Out:
# Found 4199 validated image filenames belonging to 12 classes.
# Found 901 validated image filenames belonging to 12 classes.
# Found 900 validated image filenames belonging to 12 classes.

# %%
# Initialize the MobileNetV2 model
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=img_size + (3,))  

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

# %%
# Create the model's head (top layers)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(len(set(train_labels)), activation='softmax')(x)

# %%
# Construct the final model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Setup callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='min')
model_checkpoint = ModelCheckpoint('MobileNetV2_Earth.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)

# %%
# Train the model
history=model.fit(train_gen, 
          validation_data=valid_gen, 
          epochs=100,
          steps_per_epoch=len(train_gen), 
          validation_steps=len(valid_gen),
          callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 132/132 [==============================] - ETA: 0s - loss: 0.7165 - accuracy: 0.7692
# Epoch 1: val_loss improved from inf to 0.29222, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 110s 682ms/step - loss: 0.7165 - accuracy: 0.7692 - val_loss: 0.2922 - val_accuracy: 0.9023
# Epoch 2/100
# 132/132 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8988
# Epoch 2: val_loss improved from 0.29222 to 0.21337, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 47s 358ms/step - loss: 0.3137 - accuracy: 0.8988 - val_loss: 0.2134 - val_accuracy: 0.9323
# Epoch 3/100
# 132/132 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.9138
# Epoch 3: val_loss improved from 0.21337 to 0.19919, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 49s 369ms/step - loss: 0.2646 - accuracy: 0.9138 - val_loss: 0.1992 - val_accuracy: 0.9334
# Epoch 4/100
# 132/132 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9319
# Epoch 4: val_loss improved from 0.19919 to 0.18390, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 51s 385ms/step - loss: 0.2169 - accuracy: 0.9319 - val_loss: 0.1839 - val_accuracy: 0.9367
# Epoch 5/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9383
# Epoch 5: val_loss improved from 0.18390 to 0.16360, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 50s 375ms/step - loss: 0.1938 - accuracy: 0.9383 - val_loss: 0.1636 - val_accuracy: 0.9445
# Epoch 6/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9409
# Epoch 6: val_loss improved from 0.16360 to 0.15910, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 49s 371ms/step - loss: 0.1804 - accuracy: 0.9409 - val_loss: 0.1591 - val_accuracy: 0.9456
# Epoch 7/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9428
# Epoch 7: val_loss improved from 0.15910 to 0.13472, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 49s 368ms/step - loss: 0.1690 - accuracy: 0.9428 - val_loss: 0.1347 - val_accuracy: 0.9512
# Epoch 8/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1579 - accuracy: 0.9519
# Epoch 8: val_loss improved from 0.13472 to 0.13316, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 49s 369ms/step - loss: 0.1579 - accuracy: 0.9519 - val_loss: 0.1332 - val_accuracy: 0.9589
# Epoch 9/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9500
# Epoch 9: val_loss improved from 0.13316 to 0.11856, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 49s 368ms/step - loss: 0.1598 - accuracy: 0.9500 - val_loss: 0.1186 - val_accuracy: 0.9612
# Epoch 10/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 0.9457
# Epoch 10: val_loss improved from 0.11856 to 0.10794, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 48s 364ms/step - loss: 0.1667 - accuracy: 0.9457 - val_loss: 0.1079 - val_accuracy: 0.9623
# Epoch 11/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.9533
# Epoch 11: val_loss did not improve from 0.10794
# 132/132 [==============================] - 48s 363ms/step - loss: 0.1476 - accuracy: 0.9533 - val_loss: 0.1343 - val_accuracy: 0.9545
# Epoch 12/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9545
# Epoch 12: val_loss did not improve from 0.10794
# 132/132 [==============================] - 49s 368ms/step - loss: 0.1320 - accuracy: 0.9545 - val_loss: 0.1100 - val_accuracy: 0.9656
# Epoch 13/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9562
# Epoch 13: val_loss did not improve from 0.10794
# 132/132 [==============================] - 50s 376ms/step - loss: 0.1262 - accuracy: 0.9562 - val_loss: 0.1112 - val_accuracy: 0.9589
# Epoch 14/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9524
# Epoch 14: val_loss improved from 0.10794 to 0.10476, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 48s 363ms/step - loss: 0.1400 - accuracy: 0.9524 - val_loss: 0.1048 - val_accuracy: 0.9634
# Epoch 15/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9564
# Epoch 15: val_loss did not improve from 0.10476
# 132/132 [==============================] - 48s 366ms/step - loss: 0.1265 - accuracy: 0.9564 - val_loss: 0.1154 - val_accuracy: 0.9623
# Epoch 16/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9555
# Epoch 16: val_loss improved from 0.10476 to 0.10131, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 48s 363ms/step - loss: 0.1239 - accuracy: 0.9555 - val_loss: 0.1013 - val_accuracy: 0.9645
# Epoch 17/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9533
# Epoch 17: val_loss did not improve from 0.10131
# 132/132 [==============================] - 48s 365ms/step - loss: 0.1342 - accuracy: 0.9533 - val_loss: 0.1357 - val_accuracy: 0.9489
# Epoch 18/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9593
# Epoch 18: val_loss did not improve from 0.10131
# 132/132 [==============================] - 48s 361ms/step - loss: 0.1180 - accuracy: 0.9593 - val_loss: 0.1506 - val_accuracy: 0.9489
# Epoch 19/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.9559
# Epoch 19: val_loss did not improve from 0.10131
# 132/132 [==============================] - 48s 361ms/step - loss: 0.1282 - accuracy: 0.9559 - val_loss: 0.1326 - val_accuracy: 0.9534
# Epoch 20/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9621
# Epoch 20: val_loss did not improve from 0.10131
# 132/132 [==============================] - 50s 378ms/step - loss: 0.1197 - accuracy: 0.9621 - val_loss: 0.1063 - val_accuracy: 0.9634
# Epoch 21/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9659
# Epoch 21: val_loss did not improve from 0.10131
# 132/132 [==============================] - 51s 389ms/step - loss: 0.1024 - accuracy: 0.9659 - val_loss: 0.1140 - val_accuracy: 0.9645
# Epoch 22/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9664
# Epoch 22: val_loss did not improve from 0.10131
# 132/132 [==============================] - 75s 567ms/step - loss: 0.1032 - accuracy: 0.9664 - val_loss: 0.1310 - val_accuracy: 0.9612
# Epoch 23/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9605
# Epoch 23: val_loss did not improve from 0.10131
# 132/132 [==============================] - 51s 388ms/step - loss: 0.1095 - accuracy: 0.9605 - val_loss: 0.1043 - val_accuracy: 0.9700
# Epoch 24/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1273 - accuracy: 0.9600
# Epoch 24: val_loss did not improve from 0.10131
# 132/132 [==============================] - 47s 358ms/step - loss: 0.1273 - accuracy: 0.9600 - val_loss: 0.1244 - val_accuracy: 0.9600
# Epoch 25/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9645
# Epoch 25: val_loss did not improve from 0.10131
# 132/132 [==============================] - 47s 359ms/step - loss: 0.1018 - accuracy: 0.9645 - val_loss: 0.1227 - val_accuracy: 0.9578
# Epoch 26/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 0.9686
# Epoch 26: val_loss did not improve from 0.10131
# 132/132 [==============================] - 50s 378ms/step - loss: 0.0973 - accuracy: 0.9686 - val_loss: 0.1083 - val_accuracy: 0.9700
# Epoch 27/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9674
# Epoch 27: val_loss did not improve from 0.10131
# 132/132 [==============================] - 54s 409ms/step - loss: 0.0959 - accuracy: 0.9674 - val_loss: 0.1476 - val_accuracy: 0.9600
# Epoch 28/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.9638
# Epoch 28: val_loss improved from 0.10131 to 0.09632, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 60s 454ms/step - loss: 0.1143 - accuracy: 0.9638 - val_loss: 0.0963 - val_accuracy: 0.9656
# Epoch 29/100
# Epoch 50/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9736
# Epoch 50: val_loss did not improve from 0.08611
# 132/132 [==============================] - 62s 466ms/step - loss: 0.0884 - accuracy: 0.9736 - val_loss: 0.0903 - val_accuracy: 0.9700
# Epoch 51/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9719
# Epoch 51: val_loss did not improve from 0.08611
# 132/132 [==============================] - 57s 435ms/step - loss: 0.0858 - accuracy: 0.9719 - val_loss: 0.1345 - val_accuracy: 0.9678
# Epoch 52/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9690
# Epoch 52: val_loss did not improve from 0.08611
# 132/132 [==============================] - 53s 399ms/step - loss: 0.1014 - accuracy: 0.9690 - val_loss: 0.0893 - val_accuracy: 0.9711
# Epoch 53/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9750
# Epoch 53: val_loss did not improve from 0.08611
# 132/132 [==============================] - 55s 413ms/step - loss: 0.0738 - accuracy: 0.9750 - val_loss: 0.0937 - val_accuracy: 0.9667
# Epoch 54/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9712
# Epoch 54: val_loss did not improve from 0.08611
# 132/132 [==============================] - 56s 424ms/step - loss: 0.0819 - accuracy: 0.9712 - val_loss: 0.1346 - val_accuracy: 0.9667
# Epoch 55/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9733
# Epoch 55: val_loss did not improve from 0.08611
# 132/132 [==============================] - 51s 386ms/step - loss: 0.0848 - accuracy: 0.9733 - val_loss: 0.0991 - val_accuracy: 0.9723
# Epoch 56/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9738
# Epoch 56: val_loss did not improve from 0.08611
# 132/132 [==============================] - 46s 351ms/step - loss: 0.0805 - accuracy: 0.9738 - val_loss: 0.0990 - val_accuracy: 0.9700
# Epoch 57/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9743
# Epoch 57: val_loss did not improve from 0.08611
# 132/132 [==============================] - 56s 421ms/step - loss: 0.0866 - accuracy: 0.9743 - val_loss: 0.1270 - val_accuracy: 0.9589
# Epoch 58/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9721
# Epoch 58: val_loss improved from 0.08611 to 0.07988, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 58s 436ms/step - loss: 0.0781 - accuracy: 0.9721 - val_loss: 0.0799 - val_accuracy: 0.9767
# Epoch 59/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9762
# Epoch 59: val_loss did not improve from 0.07988
# 132/132 [==============================] - 55s 423ms/step - loss: 0.0802 - accuracy: 0.9762 - val_loss: 0.1146 - val_accuracy: 0.9678
# Epoch 60/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9731
# Epoch 60: val_loss improved from 0.07988 to 0.07164, saving model to MobileNetV2_Earth.keras
# 132/132 [==============================] - 56s 423ms/step - loss: 0.0817 - accuracy: 0.9731 - val_loss: 0.0716 - val_accuracy: 0.9734
# Epoch 61/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9740
# Epoch 61: val_loss did not improve from 0.07164
# 132/132 [==============================] - 55s 417ms/step - loss: 0.0818 - accuracy: 0.9740 - val_loss: 0.0916 - val_accuracy: 0.9745
# Epoch 62/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0907 - accuracy: 0.9721
# Epoch 62: val_loss did not improve from 0.07164
# 132/132 [==============================] - 55s 420ms/step - loss: 0.0907 - accuracy: 0.9721 - val_loss: 0.0856 - val_accuracy: 0.9756
# Epoch 63/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9790
# Epoch 63: val_loss did not improve from 0.07164
# 132/132 [==============================] - 58s 439ms/step - loss: 0.0640 - accuracy: 0.9790 - val_loss: 0.0880 - val_accuracy: 0.9756
# Epoch 64/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9757
# Epoch 64: val_loss did not improve from 0.07164
# 132/132 [==============================] - 56s 424ms/step - loss: 0.0681 - accuracy: 0.9757 - val_loss: 0.1096 - val_accuracy: 0.9678
# Epoch 65/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9683
# Epoch 65: val_loss did not improve from 0.07164
# 132/132 [==============================] - 54s 411ms/step - loss: 0.0939 - accuracy: 0.9683 - val_loss: 0.0815 - val_accuracy: 0.9734
# Epoch 66/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9740
# Epoch 66: val_loss did not improve from 0.07164
# 132/132 [==============================] - 58s 441ms/step - loss: 0.0816 - accuracy: 0.9740 - val_loss: 0.1119 - val_accuracy: 0.9711
# Epoch 67/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9762
# Epoch 67: val_loss did not improve from 0.07164
# 132/132 [==============================] - 59s 447ms/step - loss: 0.0767 - accuracy: 0.9762 - val_loss: 0.0901 - val_accuracy: 0.9734
# Epoch 68/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9748
# Epoch 68: val_loss did not improve from 0.07164
# 132/132 [==============================] - 59s 449ms/step - loss: 0.0764 - accuracy: 0.9748 - val_loss: 0.1248 - val_accuracy: 0.9656
# Epoch 69/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9786
# Epoch 69: val_loss did not improve from 0.07164
# 132/132 [==============================] - 54s 412ms/step - loss: 0.0668 - accuracy: 0.9786 - val_loss: 0.0977 - val_accuracy: 0.9734
# Epoch 70/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9812
# Epoch 70: val_loss did not improve from 0.07164
# 132/132 [==============================] - 57s 432ms/step - loss: 0.0602 - accuracy: 0.9812 - val_loss: 0.0898 - val_accuracy: 0.9700
# Epoch 71/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9774
# Epoch 71: val_loss did not improve from 0.07164
# 132/132 [==============================] - 54s 409ms/step - loss: 0.0689 - accuracy: 0.9774 - val_loss: 0.0997 - val_accuracy: 0.9700
# Epoch 72/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9783
# Epoch 72: val_loss did not improve from 0.07164
# 132/132 [==============================] - 54s 412ms/step - loss: 0.0640 - accuracy: 0.9783 - val_loss: 0.0820 - val_accuracy: 0.9778
# Epoch 73/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9748
# Epoch 73: val_loss did not improve from 0.07164
# 132/132 [==============================] - 54s 409ms/step - loss: 0.0857 - accuracy: 0.9748 - val_loss: 0.0994 - val_accuracy: 0.9678
# Epoch 74/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9771
# Epoch 74: val_loss did not improve from 0.07164
# 132/132 [==============================] - 54s 411ms/step - loss: 0.0766 - accuracy: 0.9771 - val_loss: 0.1212 - val_accuracy: 0.9689
# Epoch 75/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9762
# Epoch 75: val_loss did not improve from 0.07164
# 132/132 [==============================] - 54s 411ms/step - loss: 0.0763 - accuracy: 0.9762 - val_loss: 0.1321 - val_accuracy: 0.9678
# Epoch 76/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9736
# Epoch 76: val_loss did not improve from 0.07164
# 132/132 [==============================] - 59s 446ms/step - loss: 0.0774 - accuracy: 0.9736 - val_loss: 0.1628 - val_accuracy: 0.9567
# Epoch 77/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9769
# Epoch 77: val_loss did not improve from 0.07164
# 132/132 [==============================] - 58s 442ms/step - loss: 0.0713 - accuracy: 0.9769 - val_loss: 0.0887 - val_accuracy: 0.9723
# Epoch 78/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9764
# Epoch 78: val_loss did not improve from 0.07164
# 132/132 [==============================] - 54s 412ms/step - loss: 0.0758 - accuracy: 0.9764 - val_loss: 0.0903 - val_accuracy: 0.9756
# Epoch 79/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9759
# Epoch 79: val_loss did not improve from 0.07164
# 132/132 [==============================] - 52s 393ms/step - loss: 0.0751 - accuracy: 0.9759 - val_loss: 0.1190 - val_accuracy: 0.9656
# Epoch 80/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9776
# Epoch 80: val_loss did not improve from 0.07164
# 132/132 [==============================] - 52s 390ms/step - loss: 0.0703 - accuracy: 0.9776 - val_loss: 0.0944 - val_accuracy: 0.9723
# Epoch 80: early stopping

# %%
from tensorflow.keras.models import load_model
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %%
model = load_model('MobileNetV2_Earth.keras')

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_gen, steps=len(test_gen))

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)


# Predict the test set
test_preds = model.predict(test_gen, steps=len(test_gen))

# Convert predictions from one-hot encoded vectors to class indices
predicted_classes = np.argmax(test_preds, axis=1)

# Retrieve true class labels from the test generator
true_classes = test_gen.classes

# Class labels (ensure these are in the same order as the generator's classes)
class_labels = list(test_gen.class_indices.keys())

# Confusion Matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)

# Plot Confusion Matrix
plt.figure(figsize=(4, 4))
sns.set(font_scale=1.2)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix of MobileNetv2')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# Classification Report
class_report = classification_report(true_classes, predicted_classes, target_names=class_labels)

print("\nClassification Report:")
print(class_report)
# Out:
# 29/29 [==============================] - 11s 365ms/step - loss: 0.1284 - accuracy: 0.9722
# Test Loss: 0.1283894032239914
# Test Accuracy: 0.9722222089767456
# 29/29 [==============================] - 2s 42ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#      Highway       0.99      1.00      0.99        80
#      airport       0.97      0.98      0.97        96
#        beach       1.00      0.97      0.99        69
#       bridge       0.94      0.97      0.96        88
#    buildings       1.00      1.00      1.00        85
#     farmland       0.98      0.93      0.96        70
#       forest       0.97      0.92      0.94        62
#  harbor_port       0.97      0.99      0.98        71
#       island       0.96      0.98      0.97        66
#         lake       0.99      0.97      0.98        80
#     mountain       0.94      0.97      0.95        64
#        river       0.96      0.97      0.96        69
#
#     accuracy                           0.97       900
#    macro avg       0.97      0.97      0.97       900
# weighted avg       0.97      0.97      0.97       900

# %%
import matplotlib.pyplot as plt

# Extracting data from the history object
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Finding the best epoch (the one with the lowest validation loss)
best_epoch = val_loss.index(min(val_loss)) + 1

# Plotting training and validation accuracy
plt.figure(figsize=(14, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, label='Training Accuracy', color='blue')
plt.plot(epochs, val_acc, label='Validation Accuracy', color='orange')
plt.scatter(best_epoch, val_acc[best_epoch - 1], color='red', zorder=5)  # Mark the best epoch
plt.text(best_epoch, val_acc[best_epoch - 1], f'Best epoch = {best_epoch}', color='red', ha='center', va='bottom')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss', color='blue')
plt.plot(epochs, val_loss, label='Validation Loss', color='orange')
plt.scatter(best_epoch, val_loss[best_epoch - 1], color='red', zorder=5)  # Mark the best epoch
plt.text(best_epoch, val_loss[best_epoch - 1], f'Best epoch = {best_epoch}', color='red', ha='center', va='top')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
model.save('MobileNetv2Earth.h5')
